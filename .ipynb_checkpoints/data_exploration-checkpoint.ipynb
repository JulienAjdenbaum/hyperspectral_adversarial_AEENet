# %%
from spectral import *
import os
import numpy as np
import matplotlib.pyplot as plt
import scipy.io
from ER_superpixel_segmentation.main import ER_SS_main
import scipy.io

# %%
# file_dir = "data/samson/samson_1.img.hdr"
file_dir = "data/jasper/jasperRidge2_F224.hdr"
# file_dir = "/home/julien/Downloads/jasperRidge2_F224 (1)/jasperRidge2_F224/jasperRidge2_F224.hdr"
img = open_image(file_dir)
print(f"\nThe image shape is {img.shape}")

plt.bar(img.bands.centers, np.ones(len(img.bands.centers)))
plt.title("Bands")
plt.xlabel("Bands centers (nm)")
plt.show()

view = imshow(img)
print(view)
plt.show()
# Out:
# The image shape is (100, 100, 224)
# ImageView object:
#   Display bands       :  [35, 20, 7]
#   Interpolation       :  <default>
#   RGB data limits     :
#     R: [0.0189, 0.3343]
#     G: [0.026, 0.252]
#     B: [0.011, 0.1446]

# %%
mat = scipy.io.loadmat('/home/julien/Downloads/jasperRidge2_F224_2.mat')
path_img = 'data/jasper/jasper.mat'
mat = scipy.io.loadmat(path_img)
img = mat["Y"].reshape(mat["Y"].shape[0], int(np.sqrt(mat["Y"].shape[1])), int(np.sqrt(mat["Y"].shape[1])))
img = img.astype(np.float32)/np.max(img)

# %%
bands = [35, 20, 7]
#         n_bands = 100
#         bands = np.arange(0, n_bands)
img_color = np.stack((img[bands[0]], img[bands[1]], img[bands[2]]), axis=-1)
img_color.shape
print(np.unique(img_color, axis=2))
# Out:
# [[[0.05278646 0.1171602  0.13279381]
#   [0.04837226 0.12139047 0.14382932]
#   [0.04855619 0.1134817  0.13187419]
#   ...
#   [0.02556557 0.06308626 0.05297039]
#   [0.02795659 0.06915578 0.05867206]
#   [0.02795659 0.06676476 0.05554534]]
#
#  [[0.05094721 0.1134817  0.12635645]
#   [0.04837226 0.10649255 0.11807983]
#   [0.04450984 0.1031819  0.10778002]
#   ...
#   [0.02758874 0.06308626 0.04653301]
#   [0.02979584 0.07265036 0.05683281]
#   [0.02795659 0.07025933 0.05370609]]
#
#  [[0.04267059 0.09876771 0.09711238]
#   [0.04248666 0.09766416 0.10263012]
#   [0.04248666 0.09012323 0.08975538]
#   ...
#   [0.02556557 0.06639691 0.05480964]
#   [0.02795659 0.07430568 0.05591319]
#   [0.03181902 0.07540923 0.05370609]]
#
#  ...
#
#  [[0.08055913 0.11991908 0.14143829]
#   [0.07614493 0.1267243  0.16111827]
#   [0.10446937 0.14419717 0.15560052]
#   ...
#   [0.04267059 0.09196248 0.09196248]
#   [0.05297039 0.1075961  0.12948318]
#   [0.04506161 0.09233033 0.0958249 ]]
#
#  [[0.12690823 0.18337318 0.2196064 ]
#   [0.09416958 0.15817547 0.19404083]
#   [0.1024462  0.14088652 0.15284164]
#   ...
#   [0.04267059 0.0884679  0.0892036 ]
#   [0.05094721 0.10079088 0.10869965]
#   [0.05094721 0.10520507 0.10373367]]
#
#  [[0.17123413 0.24186131 0.27349642]
#   [0.08000736 0.13279381 0.15210594]
#   [0.09839986 0.13647231 0.15118632]
#   ...
#   [0.04064742 0.08313408 0.07908773]
#   [0.03696892 0.08681258 0.07798418]
#   [0.03696892 0.0914107  0.07890381]]]

# %%
plt.imshow(np.load("data/jasper/jasper_100_seg.npy"), cmap="tab20")
plt.plot()
# Out:
# []

# %%
path_img = 'data/jasper/jasper.mat'
mat = scipy.io.loadmat(path_img)
img = mat["Y"].reshape(mat["Y"].shape[0], int(np.sqrt(mat["Y"].shape[1])), int(np.sqrt(mat["Y"].shape[1])))
img = img.astype(np.float32)/np.max(img)

from VCA import vca

print(img.shape)
Ae, indice, Yp = vca(img.reshape((img.shape[0], 10000)),6)

print(Ae.shape)
print(indice)
for i in range(Ae.shape[0]):
    plt.plot(Ae[:, i])
# Out:
# (224, 100, 100)
# SNR estimated = 31.866592775797535[dB]
# ... Select the projective proj.
# (224, 6)
# [4590 1161   85  392 4194 5267]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [9], in <cell line: 13>()
#      12 print(indice)
#      13 for i in range(Ae.shape[0]):
# ---> 14     plt.plot(Ae[:, i])
#
# IndexError: index 6 is out of bounds for axis 1 with size 6

# %%
path_img = "/home/julien/Documents/Hyperspectral/data/jasper/jasper.mat"
n_superpixels = 100
data_location = "Y"
bands = [35, 20, 7]
ER_SS_main(path_img, data_location, n_superpixels, bands)

path_img = "/home/julien/Documents/Hyperspectral/data/samson/samson.mat"
n_superpixels = 100
data_location = "V"
bands = [85, 50, 10]
    
ER_SS_main(path_img, data_location, n_superpixels, bands)
# Out:
# 0.0
# 0.02538006649577422
# 0.05076013299154844
# 0.07614019948732266
# 0.10152026598309688
# 0.1269003324788711
# 0.15228039897464532
# 0.17766046547041953
# 0.20304053196619376
# 0.22842059846196797
# 0.2538006649577422
# 0.2791807314535164
# 0.30456079794929064
# 0.3299408644450648
# 0.35532093094083905
# 0.3807009974366133
# 0.4060810639323875
# 0.4314611304281617
# 0.45684119692393593
# 0.48222126341971017
# 0.5076013299154843
# 0.5329813964112586
# 0.5583614629070328
# 0.583741529402807
# 0.6091215958985813
# 0.6345016623943555
# 0.6598817288901296
# 0.6852617953859039
# 0.7106418618816781
# 0.7360219283774524
# 0.7614019948732266
# 0.7867820613690008
# 0.812162127864775
# 0.8375421943605492
# 0.8629222608563234
# 0.8883023273520977
# 0.9136823938478719
# 0.9390624603436462
# 0.9644425268394203
# 0.9898225933351945
# mean duration of init_heap is 0.11964845657348633 repeated 1
# mean duration of iterate_until_end is 1.142345905303955 repeated 1
# mean duration of update_heap is 1.1425135135650635 repeated 1
# 0.0
# 0.028143645164921762
# 0.056287290329843524
# 0.08443093549476528
# 0.11257458065968705
# 0.1407182258246088
# 0.16886187098953057
# 0.19700551615445233
# 0.2251491613193741
# 0.25329280648429586
# 0.2814364516492176
# 0.3095800968141394
# 0.33772374197906113
# 0.36586738714398287
# 0.39401103230890466
# 0.4221546774738264
# 0.4502983226387482
# 0.47844196780366993
# 0.5065856129685917
# 0.5347292581335135
# 0.5628729032984352
# 0.5910165484633569
# 0.6191601936282788
# 0.6473038387932005
# 0.6754474839581223
# 0.703591129123044
# 0.7317347742879657
# 0.7598784194528876
# 0.7880220646178093
# 0.8161657097827311
# 0.8443093549476528
# 0.8724530001125745
# 0.9005966452774964
# 0.9287402904424181
# 0.9568839356073399
# 0.9850275807722616
# mean duration of init_heap is 0.10387659072875977 repeated 1
# mean duration of iterate_until_end is 1.2847893238067627 repeated 1
# mean duration of update_heap is 1.2849483489990234 repeated 1
